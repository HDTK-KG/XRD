# %%
import os, sys
exec("""
current = os.path.abspath('.')
while current != os.path.dirname(current):
    if any(os.path.exists(os.path.join(current, marker)) for marker in ['.git', 'utils', 'pyproject.toml']):
        if current not in sys.path: sys.path.insert(0, current)
        utils_path = os.path.join(current, 'utils')
        if os.path.exists(utils_path) and utils_path not in sys.path: sys.path.insert(0, utils_path)
        break
    current = os.path.dirname(current)
""")

# 上記の1行実行後は、通常通りインポート可能
import ras2csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import importlib

importlib.reload(ras2csv)

# 現在のディレクトリ（sampleフォルダ）を指定して一括変換を実行
current_folder = os.getcwd()
print(f"📁 対象フォルダ: {current_folder}")
print()

# フォルダ内の全ての.rasファイルを一括変換
results = ras2csv.ras2csv_json_all(current_folder)
# Out:
# 📁 対象フォルダ: c:\Users\kg315\Documents\GitHub\XRD\sample
#
# 📁 フォルダ内の.rasファイルを検索中: c:\Users\kg315\Documents\GitHub\XRD\sample
# 🔍 1個の.rasファイルを発見しました
#
# 📄 処理中: CsV3Sb5_0T_20241208.ras
# JSONファイルを作成しました: c:\Users\kg315\Documents\GitHub\XRD\sample\CsV3Sb5_0T_20241208.json
# CSVファイルを作成しました: c:\Users\kg315\Documents\GitHub\XRD\sample\CsV3Sb5_0T_20241208.csv
# ✅ 変換完了: CsV3Sb5_0T_20241208.json, CsV3Sb5_0T_20241208.csv
#
# 📊 処理結果:
#    ✅ 成功: 1ファイル
#    ❌ エラー: 0ファイル
#    📁 出力先: c:\Users\kg315\Documents\GitHub\XRD\sample

# %%
# 新機能: ras2csv_json_all のテスト
# まず、utilsモジュールを更新
import importlib
importlib.reload(ras2csv)

# 現在のディレクトリ（sampleフォルダ）を指定して一括変換を実行
current_folder = os.getcwd()
print(f"📁 対象フォルダ: {current_folder}")
print()

# フォルダ内の全ての.rasファイルを一括変換
results = ras2csv.ras2csv_json_all(current_folder)

# 結果の詳細表示
if results:
    print("\n" + "="*50)
    print("📋 変換結果の詳細:")
    print("="*50)
    
    for i, result in enumerate(results, 1):
        status = "✅ 成功" if result['success'] else "❌ 失敗"
        filename = os.path.basename(result['ras_file'])
        print(f"{i}. {status}: {filename}")
        
        if result['success']:
            json_file = os.path.basename(result['json_file'])
            csv_file = os.path.basename(result['csv_file'])
            print(f"   → JSON: {json_file}")
            print(f"   → CSV:  {csv_file}")
        else:
            print(f"   エラー: {result['error']}")
        print()
else:
    print("処理対象のファイルがありませんでした。")
# Out:
# 📁 対象フォルダ: c:\Users\kg315\Documents\GitHub\XRD\sample
#
# 📁 フォルダ内の.rasファイルを検索中: c:\Users\kg315\Documents\GitHub\XRD\sample
# 🔍 1個の.rasファイルを発見しました
#
# 📄 処理中: CsV3Sb5_0T_20241208.ras
# JSONファイルを作成しました: c:\Users\kg315\Documents\GitHub\XRD\sample\CsV3Sb5_0T_20241208.json
# CSVファイルを作成しました: c:\Users\kg315\Documents\GitHub\XRD\sample\CsV3Sb5_0T_20241208.csv
# ✅ 変換完了: CsV3Sb5_0T_20241208.json, CsV3Sb5_0T_20241208.csv
#
# 📊 処理結果:
#    ✅ 成功: 1ファイル
#    ❌ エラー: 0ファイル
#    📁 出力先: c:\Users\kg315\Documents\GitHub\XRD\sample
#
# ==================================================
# 📋 変換結果の詳細:
# ==================================================
# 1. ✅ 成功: CsV3Sb5_0T_20241208.ras
#    → JSON: CsV3Sb5_0T_20241208.json
#    → CSV:  CsV3Sb5_0T_20241208.csv
